# %%
import boto3
import awswrangler as wr
import pandas as pd
accessKeys = pd.read_csv("../../../quant-bears_accessKeys.csv")
session = boto3.Session(
	aws_access_key_id=accessKeys.loc[0, "Access key ID"],
	aws_secret_access_key=accessKeys.loc[0, "Secret access key"]
)

s3_collection_path = "s3://quant-bears-data-collection/raw-data/"

# %%
df_alpha = wr.s3.read_parquet(s3_collection_path + "seekingAlpha.seekingAlphaBulkMetrics/2023-10-02.parquet", boto3_session=session)
df_guru = wr.s3.read_parquet(s3_collection_path + "gurufocus/2023-10-02.parquet", boto3_session=session)

# %%
df_guru["Avg_Volume__2M_"].describe()
# Out:
# count    1.576000e+03
# mean     3.374992e+06
# std      6.717153e+06
# min      0.000000e+00
# 25%      8.779700e+05
# 50%      1.560000e+06
# 75%      3.102500e+06
# max      1.142200e+08
# Name: Avg_Volume__2M_, dtype: float64

# %%
df_guru["Volume"].describe()
# Out:
# count    1.576000e+03
# mean     3.320476e+06
# std      6.496050e+06
# min      1.943600e+05
# 25%      8.353050e+05
# 50%      1.500000e+06
# 75%      3.152500e+06
# max      1.216200e+08
# Name: Volume, dtype: float64

# %%
df_guru[df_guru["Avg_Volume__2M_"] == 0.]
# Out:
#      ticker    Volume  Avg_Volume__2M_    Market_Cap  Enterprise_Value  \
# 1215   SAFE  838630.0              0.0  1.090000e+09      5.530000e+09
#
#       growth_rank  3-Year_Revenue_Growth_Rate  3-Year_EBITDA_Growth_Rate  \
# 1215          0.1                       -22.7                        0.8
#
#       3-Year_EPS_without_NRI_Growth_Rate  3-Year_FCF_Growth_Rate  ...  \
# 1215                               -23.6                     NaN  ...
#
#       Price-to-Graham-Number  Earnings_Yield__Greenblatt__%  \
# 1215                     NaN                          -1.54
#
#       Forward_Rate_of_Return__Yacktman__%       sector   area  \
# 1215                                  NaN  Real Estate  REITs
#
#       Price-to-DCF__Earnings_Based_  Price-to-DCF__FCF_Based_  \
# 1215                            NaN                       NaN
#
#       Price-to-Net-Current-Asset-Value  Price-to-Net-Cash  Price-to-FFO
# 1215                               NaN                NaN           NaN
#
# [1 rows x 74 columns]

# %%
df_guru["Enterprise_Value"].describe()
# Out:
# count    1.576000e+03
# mean     3.790269e+10
# std      1.321883e+11
# min     -2.879900e+11
# 25%      3.542500e+09
# 50%      9.250000e+09
# 75%      2.891000e+10
# max      2.720000e+12
# Name: Enterprise_Value, dtype: float64

# %%
df_guru.shape
# Out:
# (1576, 74)

# %%
df_guru["Market_Cap"]
# Out:
# 0       3.245000e+10
# 1       5.150000e+09
# 2       8.330000e+09
# 3       3.210000e+09
# 4       2.720000e+12
#             ...
# 1571    2.369000e+10
# 1572    1.968000e+10
# 1573    7.951000e+10
# 1574    1.150000e+09
# 1575    4.700000e+09
# Name: Market_Cap, Length: 1576, dtype: float64

# %%
ev_quantile_90 = df_guru["Enterprise_Value"].quantile(0.90)
ev_quantile_05 = df_guru["Enterprise_Value"].quantile(0.05)
adv_quantile_90 = df_guru["Avg_Volume__2M_"].quantile(0.90)
adv_quantile_05 = df_guru["Avg_Volume__2M_"].quantile(0.05)
ev_mask = (df_guru["Enterprise_Value"] < ev_quantile_90) & (df_guru["Enterprise_Value"] > ev_quantile_05)
adv_mask = (df_guru["Avg_Volume__2M_"] < adv_quantile_90) & (df_guru["Avg_Volume__2M_"] > adv_quantile_05)
robust_guru_df  = df_guru[ev_mask & adv_mask]

# %%
robust_guru_df.plot.scatter(x = "Enterprise_Value", y = "Avg_Volume__2M_")
# Out:
# <Axes: xlabel='Enterprise_Value', ylabel='Avg_Volume__2M_'>

# %%
df_guru["sector"].value_counts().plot(kind="bar")
# Stratify by sector
# Out:
# <Axes: xlabel='sector'>

# %%
df_guru = df_guru.set_index("ticker")
df_alpha = df_alpha.set_index("ticker")

# %%
joined_df = pd.concat([df_guru, df_alpha], axis = 1)
joined_df.shape
# Out:
# (1576, 337)

# %%
sectors = pd.get_dummies(joined_df["sector"]).astype("float").add_prefix("sector_")

# %%
joined_df = pd.concat([joined_df, sectors], axis = 1)

# %%
float_df = joined_df.select_dtypes([int, float])
float_df.shape
# Out:
# (1576, 346)

# %%
def plot_corr(df,size=10):
    '''Plot a graphical correlation matrix for a dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''
    
    # %matplotlib inline
    import matplotlib.pyplot as plt

    # Compute the correlation matrix for the received dataframe
    corr = df.corr()
    
    # Plot the correlation matrix
    fig, ax = plt.subplots(figsize=(size, size))
    cax = ax.matshow(corr, cmap='RdYlGn')
    # plt.xticks(range(len(corr.columns)), corr.columns, rotation=90);
    # plt.yticks(range(len(corr.columns)), corr.columns);
    
    # Add the colorbar legend
    cbar = fig.colorbar(cax, ticks=[-1, 0, 1], aspect=40, shrink=.8)
    return fig

# %%
import scipy
import numpy as np
import scipy.cluster.hierarchy as sch

float_df = float_df.fillna(0.)

X = float_df.corr().values
d = sch.distance.pdist(X)   # vector of ('55' choose 2) pairwise distances
L = sch.linkage(d, method='complete')
ind = sch.fcluster(L, 0.5*d.max(), 'distance')
columns = [float_df.columns.tolist()[i] for i in list((np.argsort(ind)))]
float_df = float_df.reindex(columns = columns)

# %%
plot_corr(float_df)
pass

# %%
corr_df = float_df.corr().abs()

# %%
from tqdm import tqdm

# %%
cols_to_remove = set()
corr_threshold = .95

for col in tqdm(float_df.columns):
	if col in cols_to_remove:
		continue
	exceeded_values = corr_df.columns[(corr_df.loc[col] > corr_threshold)]
	if exceeded_values.shape[0] > 1:
		new_cols = set(exceeded_values.tolist())
		new_cols.remove(col)
		cols_to_remove = cols_to_remove.union(new_cols)
# Out:
# 100%|██████████| 346/346 [00:00<00:00, 23043.80it/s]

# %%
len(cols_to_remove)
# Out:
# 60

# %%
high_corr_filtered_df = float_df.drop(list(cols_to_remove), axis = 1)

# %%
plot_corr(high_corr_filtered_df)
pass

# %%
high_corr_filtered_df.shape
# Out:
# (1576, 286)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize, minmax_scale

# %%
minmax_df = pd.DataFrame(minmax_scale(high_corr_filtered_df), columns = high_corr_filtered_df.columns, index=high_corr_filtered_df.index)

# %%
plot_corr(minmax_df)
pass

# %%
data = []
weights = []
biases = []
for col in tqdm(minmax_df.columns):
	X_ = minmax_df.copy()
	X_[col] = 0.
	y = minmax_df[col]
	linreg = LinearRegression()
	linreg.fit(X_, y)
	y_pred = linreg.predict(X_)
	y_residual = y - y_pred
	data.append(y_residual)
	weights.append(linreg.coef_)
	biases.append(linreg.intercept_)
# Out:
# 100%|██████████| 286/286 [00:19<00:00, 14.80it/s]

# %%
residual_df = pd.DataFrame(data, index = minmax_df.columns).T
residual_df.head()
# Out:
#         ev_sales_fy1  EV-to-Forward-Revenue  capex_to_sales  \
# ticker
# A          -0.000590               0.001238        0.000354
# AA         -0.001625               0.005370       -0.002177
# AAL        -0.003554              -0.001263        0.000110
# AAP         0.002781              -0.001275        0.000355
# AAPL        0.002130              -0.001232       -0.000278
#
#         capex_change_avg_5y  ps_ratio  PS_Ratio  Days_Payable  \
# ticker
# A                  0.000559  0.002641 -0.000570      0.001189
# AA                 0.002878  0.004160 -0.003148     -0.008002
# AAL                0.001538  0.001752 -0.001606      0.003938
# AAP                0.000682  0.000204 -0.000317     -0.002343
# AAPL               0.002389  0.002554 -0.002005      0.001312
#
#         revenue_change_display  Days_Inventory  cf_op_change_display_avg_5y  \
# ticker
# A                     0.000757       -0.000409                    -0.001108
# AA                   -0.000565        0.004204                    -0.027167
# AAL                  -0.003848       -0.002877                     0.016871
# AAP                  -0.000746        0.003978                     0.001328
# AAPL                 -0.002086       -0.002007                     0.003093
#
#         ...  cash_from_operations_as_reported  \
# ticker  ...
# A       ...                          0.008994
# AA      ...                          0.005255
# AAL     ...                         -0.009882
# AAP     ...                         -0.009265
# AAPL    ...                         -0.020569
#
#         cash_from_operations_as_reported_avg_5y  Market_Cap    ebitda  \
# ticker
# A                                      0.010074   -0.001960 -0.005256
# AA                                    -0.008562    0.009456 -0.004883
# AAL                                   -0.016074   -0.023585  0.008283
# AAP                                   -0.024614    0.031936 -0.010057
# AAPL                                   0.034744    0.154633 -0.045639
#
#         authors_count  levered_free_cash_flow  net_income  \
# ticker
# A            0.024176               -0.003165   -0.003718
# AA          -0.013631                0.000183   -0.004112
# AAL         -0.009178                0.011194    0.007311
# AAP          0.031309               -0.015775   -0.005473
# AAPL        -0.067274                0.131073    0.068977
#
#         number_of_employees  total_revenue  gross_profit
# ticker
# A                 -0.001707      -0.001553      0.006417
# AA                -0.003445      -0.004332      0.007441
# AAL                0.011591       0.014618     -0.010987
# AAP               -0.018541      -0.000258      0.018115
# AAPL              -0.000293       0.060462     -0.106256
#
# [5 rows x 286 columns]

# %%
plot_corr(residual_df)
pass

# %%
residual_df.corrwith(minmax_df).sort_values(ascending = False).describe()
# Out:
# count    286.000000
# mean       0.548215
# std        0.269399
# min       -0.311323
# 25%        0.334102
# 50%        0.560816
# 75%        0.768119
# max        0.975655
# dtype: float64

# %%
coef_df = pd.DataFrame(weights, columns = minmax_df.columns, index = "coefs_for_" + minmax_df.columns).T
coef_df.tail()
# Out:
#                         coefs_for_ev_sales_fy1  \
# levered_free_cash_flow               -0.004169
# net_income                            0.010979
# number_of_employees                  -0.005548
# total_revenue                         0.005258
# gross_profit                          0.018198
#
#                         coefs_for_EV-to-Forward-Revenue  \
# levered_free_cash_flow                         0.008406
# net_income                                    -0.014080
# number_of_employees                            0.009055
# total_revenue                                 -0.006776
# gross_profit                                  -0.017858
#
#                         coefs_for_capex_to_sales  \
# levered_free_cash_flow                 -0.003697
# net_income                             -0.006036
# number_of_employees                    -0.001231
# total_revenue                           0.001353
# gross_profit                            0.001328
#
#                         coefs_for_capex_change_avg_5y  coefs_for_ps_ratio  \
# levered_free_cash_flow                       0.000133           -0.002496
# net_income                                   0.006476            0.008406
# number_of_employees                          0.001379            0.002479
# total_revenue                               -0.001981           -0.002953
# gross_profit                                -0.001131           -0.003754
#
#                         coefs_for_PS_Ratio  coefs_for_Days_Payable  \
# levered_free_cash_flow            0.004047                0.011791
# net_income                       -0.002036                0.009628
# number_of_employees              -0.001604               -0.000408
# total_revenue                    -0.000450                0.001877
# gross_profit                      0.004384                0.009486
#
#                         coefs_for_revenue_change_display  \
# levered_free_cash_flow                          0.007225
# net_income                                     -0.015238
# number_of_employees                            -0.000076
# total_revenue                                   0.006584
# gross_profit                                   -0.000966
#
#                         coefs_for_Days_Inventory  \
# levered_free_cash_flow                 -0.006018
# net_income                             -0.003509
# number_of_employees                     0.000342
# total_revenue                          -0.004269
# gross_profit                           -0.004380
#
#                         coefs_for_cf_op_change_display_avg_5y  ...  \
# levered_free_cash_flow                               0.003876  ...
# net_income                                           0.003624  ...
# number_of_employees                                 -0.023121  ...
# total_revenue                                        0.002075  ...
# gross_profit                                         0.049507  ...
#
#                         coefs_for_cash_from_operations_as_reported  \
# levered_free_cash_flow                                    0.040123
# net_income                                                0.153229
# number_of_employees                                      -0.065160
# total_revenue                                             0.041443
# gross_profit                                              0.157275
#
#                         coefs_for_cash_from_operations_as_reported_avg_5y  \
# levered_free_cash_flow                                          -0.041891
# net_income                                                       0.081469
# number_of_employees                                              0.030362
# total_revenue                                                    0.017100
# gross_profit                                                     0.064801
#
#                         coefs_for_Market_Cap  coefs_for_ebitda  \
# levered_free_cash_flow              0.172482          0.228437
# net_income                          0.448087          0.334678
# number_of_employees                 0.071082         -0.144673
# total_revenue                      -0.138600          0.068512
# gross_profit                        0.117619          0.372985
#
#                         coefs_for_authors_count  \
# levered_free_cash_flow                 0.103610
# net_income                             0.154161
# number_of_employees                   -0.072107
# total_revenue                          0.052867
# gross_profit                          -0.003522
#
#                         coefs_for_levered_free_cash_flow  \
# levered_free_cash_flow                      4.857226e-17
# net_income                                  8.527901e-02
# number_of_employees                        -9.088740e-02
# total_revenue                               1.177089e-01
# gross_profit                                2.203476e-02
#
#                         coefs_for_net_income  coefs_for_number_of_employees  \
# levered_free_cash_flow          4.814581e-02                  -1.275638e-01
# net_income                     -5.204170e-18                  -2.241699e-01
# number_of_employees            -9.014797e-02                   7.806256e-18
# total_revenue                   2.527537e-02                   4.375667e-01
# gross_profit                    3.196681e-02                   5.341035e-01
#
#                         coefs_for_total_revenue  coefs_for_gross_profit
# levered_free_cash_flow                 0.174571                0.014445
# net_income                             0.066363                0.037055
# number_of_employees                    0.462288                0.249045
# total_revenue                          0.000000                0.215723
# gross_profit                           0.488791                0.000000
#
# [5 rows x 286 columns]

# %%
intercept_series = pd.Series(biases, index = "intercepts_for_" + minmax_df.columns)

# %%
intercept_series
# Out:
# intercepts_for_ev_sales_fy1              1.223635e+10
# intercepts_for_EV-to-Forward-Revenue    -3.164577e+10
# intercepts_for_capex_to_sales            5.733475e+08
# intercepts_for_capex_change_avg_5y      -8.320956e+11
# intercepts_for_ps_ratio                  8.482547e+11
#                                              ...
# intercepts_for_levered_free_cash_flow   -3.027860e+10
# intercepts_for_net_income                4.940780e+10
# intercepts_for_number_of_employees       6.716833e+09
# intercepts_for_total_revenue             1.611548e+10
# intercepts_for_gross_profit              9.037462e+09
# Length: 286, dtype: float64

# %%
corr_df.abs().mean().sort_values().head(30)
# Out:
# levered_free_cash_flow_yoy           0.010205
# sustainable_growth_rate              0.012115
# pe_ratio                             0.012208
# diluted_eps_growth_avg_5y            0.012406
# peg_gaap_avg_5y                      0.012608
# degree_of_operating_leverage_ttm     0.013195
# levered_free_cash_flow_yoy_avg_5y    0.013218
# peg_gaap                             0.013266
# dividend_coverage_ratio_ttm          0.013490
# eps_gaap_annual_growth_yoy           0.013930
# ebitda_yoy_avg_5y                    0.014772
# op_cf_yoy                            0.014839
# working_cap_change                   0.014983
# ebitda_yoy                           0.014989
# EV-to-EBIT                           0.015088
# rtn_on_common_equity_avg_5y          0.015326
# pb_ratio_avg_5y                      0.015403
# capex_change                         0.015502
# operating_income_ebit_yoy            0.015556
# debt_eq                              0.015629
# capm_alpha_60m                       0.015994
# EV-to-FCF                            0.016495
# EV-to-EBITDA                         0.016870
# rtn_on_common_equity                 0.016998
# roe_yoy_avg_5y                       0.017175
# revenue_growth                       0.017383
# fcf_yield                            0.017961
# EV-to-Forward-EBITDA                 0.017988
# debt_eq_avg_5y                       0.018756
# ev_ebit_fy1                          0.018948
# dtype: float64

# %%
joined_df.columns[joined_df.columns.str.lower().str.contains("debt")]
# Out:
# Index(['debt_eq', 'debt_eq_avg_5y', 'net_lt_debt_ebitda',
#        'net_lt_debt_ebitda_avg_5y', 'net_lt_debt_tot_assets',
#        'net_lt_debt_tot_assets_avg_5y', 'tot_debt_cap', 'tot_debt_cap_avg_5y',
#        'total_debt'],
#       dtype='object')

# %%
joined_df["tot_debt_cap"].isna().sum()
# Out:
# 79

# %%
joined_df["dividend_coverage_ratio_ttm"].isna().sum()
# Out:
# 640

# %%
import matplotlib.pyplot as plt
joined_df.boxplot(by="sector", column = "beta24", showfliers=False, figsize=(10, 10))
plt.suptitle('')
plt.xticks(rotation = 90)
plt.ylim((-0.5, 3))
plt.ylabel("beta")
plt.title("Boxplot of beta grouped by sector")
plt.subplots_adjust(bottom = .3)
plt.savefig("beta_boxplot.png", dpi = 300)
pass

# %%
import matplotlib.pyplot as plt
joined_df.boxplot(by="sector", column = "analysts_up_percent", showfliers=False)
plt.xticks(rotation = 90)
pass

# %%
import matplotlib.pyplot as plt
joined_df.boxplot(by="sector", column = "tot_debt_cap", showfliers=False)
plt.xticks(rotation = 90)
pass

# %%
joined_df["short_interest_percent_of_float"].isna().sum()
# Out:
# 174

# %%
import matplotlib.pyplot as plt
joined_df.boxplot(by="sector", column = "altman_z_score", showfliers=False)
plt.xticks(rotation = 90)
pass

# %%
import matplotlib.pyplot as plt
joined_df.boxplot(by="sector", column = "short_interest_percent_of_float", showfliers=False)
plt.xticks(rotation = 90)
pass

# %%
# Autocorrelation plot
