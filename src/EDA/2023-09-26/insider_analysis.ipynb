# %%
import boto3
import awswrangler as wr
import pandas as pd
accessKeys = pd.read_csv("../../quant-bears_accessKeys.csv")
session = boto3.Session(
	aws_access_key_id=accessKeys.loc[0, "Access key ID"],
	aws_secret_access_key=accessKeys.loc[0, "Secret access key"]
)

s3_collection_path = "s3://quant-bears-data-collection/raw-data/"

# %%
source = "discountingCashFlows.dcfInsiderTrading/"

df = wr.s3.read_parquet(s3_collection_path + source + "2023-09-26.parquet", boto3_session=session)

# %%
df["transacted_shares"] = df["Shrs._Transacted"].str.replace(",", "").astype("float")
df["owned_shares"] = df["Shrs._Owned"].str.replace(",", "").astype("float")

# %%
df["transacted_v_owned"] = df["transacted_shares"] / (df["owned_shares"] + 1.)

# %%
df["capped_transact_v_owned"] = df["transacted_v_owned"].clip(lower = 0.0, upper = 1.0)
df["capped_transact_v_owned"].describe()
# Out:
# count    1042.000000
# mean        0.279788
# std         0.396317
# min         0.000000
# 25%         0.009188
# 50%         0.050609
# 75%         0.419872
# max         1.000000
# Name: capped_transact_v_owned, dtype: float64

# %%
df["Type"].unique()
# Out:
# <StringArray>
# [  'P-Purchase',       'G-Gift',     'M-Exempt',       'S-Sale',
#      'F-InKind',      'A-Award',      'J-Other',             '',
#      'D-Return', 'C-Conversion']
# Length: 10, dtype: string

# %%
df["Acq./Disp."].unique()
# Out:
# <StringArray>
# ['A', 'D', '']
# Length: 3, dtype: string

# %%
df = df[df["Acq./Disp."] != ""]

# %%
df[df["Type"] == "S-Sale"]["ticker"].unique()
# Out:
# <StringArray>
# [  'AEL',  'ASAN',  'CBRL',  'CELH',  'CFLT',  'CHPT',   'CNM',   'CNO',
#   'COCO',  'COIN',  'COUR',  'CRDO',   'CRS',  'CRWD',   'CXM',   'DNA',
#     'DV',   'EDR',   'ESI',  'FROG',  'FSLY',  'GETY',  'GSHD',  'GTLB',
#   'GWRE',  'HALO',   'HCP',  'HIMS',    'HP',   'HQY',  'IBKR',   'IOT',
#  'LBTYA', 'LBTYK',   'LNW',  'LPLA',  'LSCC',  'MSGE',  'MSTR',   'MUR',
#    'NET',   'NUS',    'PI',  'PINS',    'PR',  'PROK',  'PTEN',  'PWSC',
#   'RCUS',  'RXRX',   'SCS',  'SEIC',   'SFM',  'SGEN',   'SIG',  'SMAR',
#   'SONO',  'SPLK',  'SQSP',  'STWD',  'TDOC',  'TEAM',  'TENB',  'TNET',
#    'TTD',  'ZETA',   'ZIP',    'ZM',   'ZUO']
# Length: 69, dtype: string

# %%
df[df["Type"] == "P-Purchase"]["ticker"].unique()
# Out:
# <StringArray>
# ['ABCL', 'ADC', 'ASAN', 'CHPT', 'DV', 'H', 'HPK', 'SNV', 'STAA']
# Length: 9, dtype: string

# %%
df[df["Type"] == "P-Purchase"].sort_values("capped_transact_v_owned", ascending = False)
# Out:
#     ticker Transaction_Date                           Reporting_Name  \
# 918   STAA       2023-09-21                        Lin Elizabeth Yeu
# 913    SNV       2023-09-19                               Samaha Eli
# 1      ADC       2023-09-21                          RAKOLTA JOHN JR
# 171   CHPT       2023-09-20  Q-GRG VII (CP) Investment Partners, LLC
# 476    HPK       2023-09-20                           HIGHTOWER JACK
# 477    HPK       2023-09-19                           HIGHTOWER JACK
# 388      H       2023-09-21                         TUTTLE RICHARD C
# 912    SNV       2023-09-20                               Samaha Eli
# 919   STAA       2023-09-21                 BROADWOOD PARTNERS, L.P.
# 0     ABCL       2023-09-22                         Hayden Michael R
# 921   STAA       2023-09-20                 BROADWOOD PARTNERS, L.P.
# 96    ASAN       2023-09-19                      Moskovitz Dustin A.
# 387      H       2023-09-21                         TUTTLE RICHARD C
# 908    SNV       2023-09-26                               Samaha Eli
# 910    SNV       2023-09-22                               Samaha Eli
# 911    SNV       2023-09-21                               Samaha Eli
# 286     DV       2023-09-19                            Zagorski Mark
# 909    SNV       2023-09-25                               Samaha Eli
# 478    HPK       2023-09-20                        Hollis Michael L.
# 479    HPK       2023-09-19                        Hollis Michael L.
# 923   STAA       2023-09-19                 BROADWOOD PARTNERS, L.P.
# 920   STAA       2023-09-21                 BROADWOOD PARTNERS, L.P.
# 922   STAA       2023-09-20                 BROADWOOD PARTNERS, L.P.
# 924   STAA       2023-09-19                 BROADWOOD PARTNERS, L.P.
#
#                                           Relationship Shrs._Owned  \
# 918                                           director       2,855
# 913                                   10 percent owner   1,598,082
# 1                                             director     360,056
# 171                                   10 percent owner  26,607,128
# 476  director, 10 percent owner, officer: Chief Exe...   4,358,391
# 477  director, 10 percent owner, officer: Chief Exe...   4,082,392
# 388                                           director      35,627
# 912                                   10 percent owner   1,634,507
# 919                                   10 percent owner   9,264,427
# 0                                             director   1,323,397
# 921                                   10 percent owner   9,109,613
# 96   director, 10 percent owner, officer: President...  43,932,649
# 387                                           director      35,877
# 908                                   10 percent owner   1,669,613
# 910                                   10 percent owner   1,652,427
# 911                                   10 percent owner   1,643,391
# 286         director, officer: Chief Executive Officer     357,112
# 909                                   10 percent owner   1,659,980
# 478                       director, officer: President   1,477,085
# 479                       director, officer: President   1,471,096
# 923                                   10 percent owner   8,977,534
# 920                                   10 percent owner   9,264,427
# 922                                   10 percent owner   9,109,613
# 924                                   10 percent owner   8,977,534
#
#            Type Acq./Disp. Shrs._Transacted Price__      Amount__  \
# 918  P-Purchase          A            2,500   40.00    100,000.00
# 913  P-Purchase          A          197,705   21.40  4,230,333.00
# 1    P-Purchase          A           30,000   57.48  1,724,400.00
# 171  P-Purchase          A        1,850,000    5.40  9,990,000.00
# 476  P-Purchase          A          275,999   16.55  4,567,728.00
# 477  P-Purchase          A          224,001   16.59  3,716,065.00
# 388  P-Purchase          A            1,000  104.69    104,690.00
# 912  P-Purchase          A           36,425   21.40    779,495.00
# 919  P-Purchase          A          154,814   39.62  6,133,467.00
# 0    P-Purchase          A           20,000    4.91     98,200.00
# 921  P-Purchase          A          132,079   40.67  5,372,274.00
# 96   P-Purchase          A          507,500   17.71  8,987,825.00
# 387  P-Purchase          A              250  103.70     25,925.00
# 908  P-Purchase          A            9,633   21.30    205,183.00
# 910  P-Purchase          A            9,036   21.30    192,467.00
# 911  P-Purchase          A            8,884   21.25    188,789.00
# 286  P-Purchase          A            1,765   28.36     50,055.00
# 909  P-Purchase          A            7,553   21.30    160,879.00
# 478  P-Purchase          A            5,989   16.64     99,627.00
# 479  P-Purchase          A            3,840   16.33     62,688.00
# 923  P-Purchase          A            4,490   40.89    183,613.00
# 920  P-Purchase          A                0    0.00          0.00
# 922  P-Purchase          A                0    0.00          0.00
# 924  P-Purchase          A                0    0.00          0.00
#
#      transacted_shares  owned_shares  transacted_v_owned  \
# 918             2500.0        2855.0            0.875350
# 913           197705.0     1598082.0            0.123714
# 1              30000.0      360056.0            0.083320
# 171          1850000.0    26607128.0            0.069530
# 476           275999.0     4358391.0            0.063326
# 477           224001.0     4082392.0            0.054870
# 388             1000.0       35627.0            0.028068
# 912            36425.0     1634507.0            0.022285
# 919           154814.0     9264427.0            0.016711
# 0              20000.0     1323397.0            0.015113
# 921           132079.0     9109613.0            0.014499
# 96            507500.0    43932649.0            0.011552
# 387              250.0       35877.0            0.006968
# 908             9633.0     1669613.0            0.005770
# 910             9036.0     1652427.0            0.005468
# 911             8884.0     1643391.0            0.005406
# 286             1765.0      357112.0            0.004942
# 909             7553.0     1659980.0            0.004550
# 478             5989.0     1477085.0            0.004055
# 479             3840.0     1471096.0            0.002610
# 923             4490.0     8977534.0            0.000500
# 920                0.0     9264427.0            0.000000
# 922                0.0     9109613.0            0.000000
# 924                0.0     8977534.0            0.000000
#
#      capped_transact_v_owned
# 918                 0.875350
# 913                 0.123714
# 1                   0.083320
# 171                 0.069530
# 476                 0.063326
# 477                 0.054870
# 388                 0.028068
# 912                 0.022285
# 919                 0.016711
# 0                   0.015113
# 921                 0.014499
# 96                  0.011552
# 387                 0.006968
# 908                 0.005770
# 910                 0.005468
# 911                 0.005406
# 286                 0.004942
# 909                 0.004550
# 478                 0.004055
# 479                 0.002610
# 923                 0.000500
# 920                 0.000000
# 922                 0.000000
# 924                 0.000000
